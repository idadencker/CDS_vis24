# %% [markdown]
# ## session 2.1 - defining functions

# %%
print("hello world!")

# %% [markdown]
# ### Defining function in python

# %%
def hello():
    print("hello world")

# %%
hello()
# Out:
# hello world

# %%
def hello(name):
    print("hello, " + name + "!")

# %%
hello("Ross")
# Out:
# hello, Ross!

# %%
def hello(name="world"): #giving it a default it will print if we dont give it a name, here ''world''
    print("hello, " + name +"!")

# %%
hello("ross")
# Out:
# hello, ross!

# %%
hello()
# Out:
# hello, world!

# %% [markdown]
# ### Adding explanation for good practice

# %%
#now add a docs string

def hello(name="world"): #giving it a default it will print if we dont give it a name, here ''world''
    """This function takes a name and prints it 
    """
    print("hello, " + name +"!")

# %% [markdown]
# ## exercises

# %%
# 1: What values do the variables mass and age have after each of the following statements? Test your answer by executing the lines.

mass = 47.5
age = 122
mass = mass * 2.0 #95
age = age - 20 #102

# %%
# 2: Sorting Out References. Python allows you to assign multiple values to multiple variables in one line by separating the variables and values with commas. What does the following program print out?
first, second = 'James', 'Kirk'
third, fourth = second, first
print(third, fourth)
# Out:
# Kirk James

# %%
#3: Seeing Data Types. What are the data types of the following variables? 
planet = 'Earth' #string
apples = 5 #integer
distance = 10.5 #float

# %%
# Which of the following are operators, and which are values?

* #ope
'hello' #value
-88.8 #value
- #ope
/ #ope
+ #ope
5 #value
# Out:
#   Cell In[22], line 2
#     * #ope
#       ^
# SyntaxError: invalid syntax

# %%
# 2: Which of the following is a variable, and which is a string?
spam #vari
'spam' #str

# %%
#Name three data types

#string, float, integer

# %%
#What is an expressions made up of? What fo all expressions do?

#An expression is an instruction that combines values and operators and always evaluates down to a single value.

10+2
# Out:
# 12

# %%
# What is a statement, e.g., assignment statement var = 10

#can both be an assignment e.g name= Ida or a function like print(name) etc.

# %%
#  6: what does the variable `spock` contain in the following code
spock = 20 #statement
spock + 1 #expression

#still 20, a expression does not change the value of the variable
# Out:
# 21

# %%
#7: What should the following two expressions evaluate to
'spam' + 'spamspam' #spamspamspam
'spam' * 3 #spamspamspam
# Out:
# 'spamspamspam'

# %% [markdown]
# ## working with image data

# %%
import os
import sys
sys.path.append("..")

#Opencv
import cv2
#loading some utility functions
from utils.imutils import jimshow as show

#might need to install and import matplotlib if above is not working

# %%
#Load in data
filepath= os.path.join("..","..","..","..", "cds-vis-data", "data", "img","trex.png" )

# %%
image= cv2.imread(filepath)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (228, 350, 3)

# %%
show(image)

# %%
image
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [238, 239, 243],
#         [237, 238, 242],
#         [226, 227, 234]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [238, 239, 243],
#         [237, 238, 242],
#         [231, 232, 238]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [238, 239, 243],
#         [237, 238, 242],
#         [234, 235, 240]],
#
#        ...,
#
#        [[246, 241, 238],
#         [246, 241, 238],
#         [246, 241, 238],
#         ...,
#         [242, 237, 236],
#         [242, 237, 236],
#         [242, 237, 236]],
#
#        [[246, 241, 238],
#         [246, 241, 238],
#         [246, 241, 238],
#         ...,
#         [243, 238, 237],
#         [243, 238, 237],
#         [243, 238, 237]],
#
#        [[247, 242, 239],
#         [247, 242, 239],
#         [247, 242, 239],
# ...

# %%
# save output
outpath= os.path.join("..", "output", "new_trex.png")
#save image to path
cv2.imwrite(outpath, image)
# Out:
# True

# %% [markdown]
# ### inspecting images

# %%
image.shape
# Out:
# (228, 350, 3)

# %%
height = image.shape[0]

# %%
height
# Out:
# 228

# %%
width= image.shape[1]

# %%
height*width
#number of pixels
# Out:
# 79800

# %%
#get the pixel value of all 3 channels of top left corner

image[0,0]

#Blue, green, red = BGR
# Out:
# array([254, 254, 254], dtype=uint8)

# %%
#define in a smart way
blue, green, red = image[0,0]

# %%
blue
# Out:
# 254

# %%
colors= image[0,0]

# %%
colors
# Out:
# array([254, 254, 254], dtype=uint8)

# %%
image[0,0]= (0,0,225)

# %%
show(image)
#see a little red dot in the top left corner

# %%
corner= image[0:100,0:100]

# %%
show(corner)

# %%
image[0:100,0:100]= (0,0,225)

# %%
show(image)
