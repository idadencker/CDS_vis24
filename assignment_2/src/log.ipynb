# %%
# %pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 11.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 615.4 kB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 32.6 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 37.5 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.9 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 41.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.9 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 3.3 MB/s eta 0:00:00ta 0:00:01
# ...

# %%
# sudo apt-get update
# sudo apt-get install -y python3-opencv
# pip install opencv-python matplotlib

import cv2
import matplotlib

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# 2024-03-08 15:11:55.028036: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-08 15:11:55.072344: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-08 15:11:55.072366: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-08 15:11:55.073743: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-08 15:11:55.081236: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %% [markdown]
# # Grayscaling the data

# %%
#image = cv2.imread(filename)


image = cv2.cvtColor(X_train, cv2.COLOR_BGR2GRAY)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /work/IdaHeleneDencker#2808/CDS_visual/CDS_vis24/assignment_2/src/log.ipynb Cell 5 line 4
#       <a href='vscode-notebook-cell://app-5025449-0.cloud.sdu.dk/work/IdaHeleneDencker%232808/CDS_visual/CDS_vis24/assignment_2/src/log.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> #image = cv2.imread(filename)
# ----> <a href='vscode-notebook-cell://app-5025449-0.cloud.sdu.dk/work/IdaHeleneDencker%232808/CDS_visual/CDS_vis24/assignment_2/src/log.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> image = cv2.cvtColor(X_train, cv2.COLOR_BGR2GRAY)
#
# ...

# %% [markdown]
# Preprocess the data (e.g. greyscale -save as a list of GreyScaled images by appending method, then np.array(list)
#
# for picture in
# X_train_grey, y_train_grey, X_test_grey, y_test_grey
#
#
# , normalize, reshape)

# %%
done_list_train = []

for picture in X_train:
    greyscaled= cv2.cvtColor(picture, cv2.COLOR_BGR2GRAY) 
    normalized = # normalize greyscale here
    reshaped = # reshape the nornalized image here
    done_list_train.append(reshaped)

done_list_test = []

for picture in X_test:
    greyscaled= cv2.cvtColor(picture, cv2.COLOR_BGR2GRAY) 
    normalized = # normalize greyscale here
    reshaped = # reshape the nornalized image here
    done_list_test.append(reshaped)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /work/IdaHeleneDencker#2808/CDS_visual/CDS_vis24/assignment_2/src/log.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell://app-5025449-0.cloud.sdu.dk/work/IdaHeleneDencker%232808/CDS_visual/CDS_vis24/assignment_2/src/log.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> for picture in X_train and X_test:
#       <a href='vscode-notebook-cell://app-5025449-0.cloud.sdu.dk/work/IdaHeleneDencker%232808/CDS_visual/CDS_vis24/assignment_2/src/log.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     X_train_grey = []
#       <a href='vscode-notebook-cell://app-5025449-0.cloud.sdu.dk/work/IdaHeleneDencker%232808/CDS_visual/CDS_vis24/assignment_2/src/log.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     X_test_grey = []
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#for loop going througn each image

#np.array(list)

# %%
#the images
X_train
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
# ...

# %%
X_train.shape

#after makeing the grayscaling preproccesing we want 50000,32,32)
#after making the reshaping preprocessing we want 50000, 1024

#32x32 is 1024
# Out:
# (50000, 32, 32, 3)

# %%
#when done with the classification and ready to make the report, we want to add the labels 
# check the documentation for classification report, you can actually give in an argument of a list of names
